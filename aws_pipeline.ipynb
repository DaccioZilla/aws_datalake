# %%
# !mkdir -p data

# %%
import urllib.request

def extract_data(url, filename):
  try:
    urllib.request.urlretrieve(url, filename)
  except Exception as e:
    print(e)

# %%
extract_data("https://data.boston.gov/dataset/8048697b-ad64-4bfc-b090-ee00169f2323/resource/c9509ab4-6f6d-4b97-979a-0cf2a10c922b/download/311_service_requests_2015.csv", "data/dados_2015.csv")
extract_data("https://data.boston.gov/dataset/8048697b-ad64-4bfc-b090-ee00169f2323/resource/b7ea6b1b-3ca4-4c5b-9713-6dc1db52379a/download/311_service_requests_2016.csv", "data/dados_2016.csv")
extract_data("https://data.boston.gov/dataset/8048697b-ad64-4bfc-b090-ee00169f2323/resource/30022137-709d-465e-baae-ca155b51927d/download/311_service_requests_2017.csv", "data/dados_2017.csv")
extract_data("https://data.boston.gov/dataset/8048697b-ad64-4bfc-b090-ee00169f2323/resource/2be28d90-3a90-4af1-a3f6-f28c1e25880a/download/311_service_requests_2018.csv", "data/dados_2018.csv")
extract_data("https://data.boston.gov/dataset/8048697b-ad64-4bfc-b090-ee00169f2323/resource/ea2e4696-4a2d-429c-9807-d02eb92e0222/download/311_service_requests_2019.csv", "data/dados_2019.csv")
extract_data("https://data.boston.gov/dataset/8048697b-ad64-4bfc-b090-ee00169f2323/resource/6ff6a6fd-3141-4440-a880-6f60a37fe789/download/script_105774672_20210108153400_combine.csv", "data/dados_2020.csv")

# %%
arquivos = [
    "data/dados_2015.csv",
    "data/dados_2016.csv",
    "data/dados_2017.csv",
    "data/dados_2018.csv",
    "data/dados_2019.csv",
    "data/dados_2020.csv",
]

# %%
dfs = {}

# %%
import pandas as pd

for arquivo in arquivos:
    ano = arquivo.split("_")[-1].split(".")[0]
    dfs[ano] = pd.read_csv(arquivo)

# %%
dfs['2018']
# Out:
#         case_enquiry_id              open_dt            target_dt  \
# 0          101002296861  2018-01-01 00:08:00                  NaN
# 1          101002296862  2018-01-01 00:09:46  2018-01-02 08:30:00
# 2          101002296864  2018-01-01 00:11:24  2018-01-02 08:30:00
# 3          101002296865  2018-01-01 00:19:06  2018-01-02 08:30:00
# 4          101002296866  2018-01-01 00:21:25  2018-01-02 08:30:00
# ...                 ...                  ...                  ...
# 263100     101002767849  2018-12-31 21:42:50  2019-01-03 08:30:00
# 263101     101002767851  2018-12-31 21:51:00  2019-01-03 08:30:00
# 263102     101002767852  2018-12-31 21:51:09  2019-01-03 08:30:00
# 263103     101002767854  2018-12-31 23:02:29  2019-01-03 08:30:00
# 263104     101002767855  2018-12-31 23:16:12  2019-01-03 08:30:00
#
#                   closed_dt   ontime case_status  \
# 0       2018-03-01 15:18:12   ONTIME      Closed
# 1       2018-01-02 21:15:22  OVERDUE      Closed
# 2       2018-01-02 21:15:11  OVERDUE      Closed
# 3       2018-01-02 21:14:48  OVERDUE      Closed
# 4       2018-01-02 21:14:32  OVERDUE      Closed
# ...                     ...      ...         ...
# 263100  2019-01-02 02:24:55   ONTIME      Closed
# 263101  2019-01-01 23:55:34   ONTIME      Closed
# 263102  2019-01-02 02:30:48   ONTIME      Closed
# 263103  2019-01-01 23:53:58   ONTIME      Closed
# 263104  2019-01-02 02:24:37   ONTIME      Closed
#
#                                            closure_reason  \
# 0       Case Closed. Closed date : 2018-03-01 15:18:12...
# 1       Case Closed. Closed date : 2018-01-02 21:15:22...
# 2       Case Closed. Closed date : 2018-01-02 21:15:11...
# 3       Case Closed. Closed date : 2018-01-02 21:14:48...
# 4       Case Closed. Closed date : 2018-01-02 21:14:32...
# ...                                                   ...
# 263100  Case Closed. Closed date : 2019-01-02 02:24:55...
# 263101  Case Closed. Closed date : 2019-01-01 23:55:34...
# 263102  Case Closed. Closed date : 2019-01-02 02:30:48...
# 263103  Case Closed. Closed date : 2019-01-01 23:53:58...
# 263104  Case Closed. Closed date : 2019-01-02 02:24:37...
#
#                  case_title                            subject  \
# 0              Fire Hydrant    Boston Water & Sewer Commission
# 1       Parking Enforcement  Transportation - Traffic Division
# 2       Parking Enforcement  Transportation - Traffic Division
# 3       Parking Enforcement  Transportation - Traffic Division
# 4       Parking Enforcement  Transportation - Traffic Division
# ...                     ...                                ...
# 263100  Parking Enforcement  Transportation - Traffic Division
# 263101  Parking Enforcement  Transportation - Traffic Division
# 263102  Parking Enforcement  Transportation - Traffic Division
# 263103  Parking Enforcement  Transportation - Traffic Division
# 263104  Parking Enforcement  Transportation - Traffic Division
#
#                                   reason  ... police_district  \
# 0                           Fire Hydrant  ...             E13
# 1       Enforcement & Abandoned Vehicles  ...              C6
# 2       Enforcement & Abandoned Vehicles  ...              C6
# 3       Enforcement & Abandoned Vehicles  ...              B3
# 4       Enforcement & Abandoned Vehicles  ...              B3
# ...                                  ...  ...             ...
# 263100  Enforcement & Abandoned Vehicles  ...              C6
# 263101  Enforcement & Abandoned Vehicles  ...              C6
# 263102  Enforcement & Abandoned Vehicles  ...              A1
# 263103  Enforcement & Abandoned Vehicles  ...             D14
# 263104  Enforcement & Abandoned Vehicles  ...             E13
#
#                                   neighborhood neighborhood_services_district  \
# 0                                Jamaica Plain                             11
# 1       South Boston / South Boston Waterfront                              5
# 2       South Boston / South Boston Waterfront                              5
# 3                                   Dorchester                              9
# 4                                   Dorchester                              9
# ...                                        ...                            ...
# 263100  South Boston / South Boston Waterfront                              5
# 263101  South Boston / South Boston Waterfront                              5
# 263102           Downtown / Financial District                              3
# 263103                      Allston / Brighton                             15
# 263104                           Jamaica Plain                             11
#
#            ward precinct                    location_street_name  \
# 0       Ward 19     1903                           413 Centre St
# 1        Ward 6     0604                         428 W Second St
# 2        Ward 6     0604                     401-403 W Second St
# 3            17     1701  INTERSECTION School St & Washington St
# 4       Ward 17     1701                           6-8 School St
# ...         ...      ...                                     ...
# 263100        6     0603    INTERSECTION Sherman Ct & W Broadway
# 263101   Ward 6     0607                                 60 N St
# 263102        3     0303      INTERSECTION Cross St & Hanover St
# 263103  Ward 22     2205                           45 Waverly St
# 263104  Ward 10     1009                            2 Perkins Sq
#
#        location_zipcode latitude longitude                source
# 0                2130.0  42.3214  -71.1109      Constituent Call
# 1                2127.0  42.3373  -71.0445  Citizens Connect App
# 2                2127.0  42.3371  -71.0442  Citizens Connect App
# 3                   NaN  42.3594  -71.0587  Citizens Connect App
# 4                2124.0  42.2965  -71.0729  Citizens Connect App
# ...                 ...      ...       ...                   ...
# 263100              NaN  42.3594  -71.0587  Citizens Connect App
# 263101           2127.0  42.3364  -71.0311  Citizens Connect App
# 263102              NaN  42.3594  -71.0587  Citizens Connect App
# 263103           2135.0  42.3605  -71.1427  Citizens Connect App
# 263104           2130.0  42.3213  -71.1151  Citizens Connect App
#
# [263105 rows x 29 columns]

# %% [markdown]
# Conectando a conta de armazenamento

# %%
pip install boto3
# Out:
# Collecting boto3
#   Downloading boto3-1.35.58-py3-none-any.whl.metadata (6.7 kB)
# Collecting botocore<1.36.0,>=1.35.58 (from boto3)
#   Downloading botocore-1.35.58-py3-none-any.whl.metadata (5.7 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3)
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.11.0,>=0.10.0 (from boto3)
#   Downloading s3transfer-0.10.3-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.10/dist-packages (from botocore<1.36.0,>=1.35.58->boto3) (2.8.2)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /usr/local/lib/python3.10/dist-packages (from botocore<1.36.0,>=1.35.58->boto3) (2.2.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.36.0,>=1.35.58->boto3) (1.16.0)
# Downloading boto3-1.35.58-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.2/139.2 kB 3.6 MB/s eta 0:00:00
# Downloading botocore-1.35.58-py3-none-any.whl (12.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.7/12.7 MB 54.6 MB/s eta 0:00:00
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading s3transfer-0.10.3-py3-none-any.whl (82 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.6/82.6 kB 6.0 MB/s eta 0:00:00
# Installing collected packages: jmespath, botocore, s3transfer, boto3
# Successfully installed boto3-1.35.58 botocore-1.35.58 jmespath-1.0.1 s3transfer-0.10.3

# %%
import boto3

aws_access_key_id = ''
aws_secret_access_key = ''
region_name = 'us-east-2'

boto3.setup_default_session(
    aws_access_key_id = aws_access_key_id,
    aws_secret_access_key = aws_secret_access_key,
    region_name = region_name
)
s3 = boto3.client('s3')

# %%
content = 'Olá, S3'

with open('hello-s3.txt', 'w') as f:
  f.write(content)

# %%
s3.upload_file('hello-s3.txt', 'alura-datalakeaws-curcio', 'bronze/hello-s3')

# %% [markdown]
# ### Salvar em Parquet

# %%
from io import BytesIO
for ano, df in dfs.items():
  pq_buffer = BytesIO()
  df.to_parquet(pq_buffer)

  s3.put_object(
      Bucket="alura-datalakeaws-curcio",
      Key=f"bronze/dados_{ano}.parquet",
      Body=pq_buffer.getvalue()
  )

# %%
response = s3.list_objects(Bucket= "alura-datalakeaws-curcio")
keys = [obj["Key"] for obj in response['Contents']]
keys
# Out:
# ['bronze/',
#  'bronze/dados_2015.parquet',
#  'bronze/dados_2016.parquet',
#  'bronze/dados_2017.parquet',
#  'bronze/dados_2018.parquet',
#  'bronze/dados_2019.parquet',
#  'bronze/dados_2020.parquet',
#  'bronze/hello-s3',
#  'silver/']
